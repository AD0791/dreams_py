# %%
import os
from datetime import datetime
#from datetime import date
import pymysql
from sqlalchemy import create_engine
from decouple import config 
from dotenv import load_dotenv
import pandas as pd
import numpy as np

# %%
load_dotenv()
# get the environment variables needed
USER= config('USRCaris')
PASSWORD= config('PASSCaris')
HOSTNAME= config('HOSTCaris')
DBNAME= config('DBCaris')

# get the engine to connect and fetch
engine = create_engine(f"mysql+pymysql://{USER}:{PASSWORD}@{HOSTNAME}/{DBNAME}")
query = '''
SELECT 
    p.patient_code,
    b.first_name,
    b.last_name,
    b.dob,
    dsd.a1_dat_entvyou_a_ft_jjmmaa_egz_010817 AS interview_date,
    dgs.date AS session_date,
    dg.name AS group_name,
    dh.name AS hub_name,
    lc.name AS hub_commune,
    ld.name AS hub_departement,
    dsd.f_komin AS interview_commune,
    ldt.name AS topic,
    au.email as created_by,
    au.username,
    dgs.created_at as date_session_were_entered
FROM
    caris_db.dream_group_attendance dga
        LEFT JOIN
    dream_member dm ON dm.id_patient = dga.id_patient
        LEFT JOIN
    dreams_surveys_data dsd ON dsd.case_id = dm.case_id
        LEFT JOIN
    dream_group_session dgs ON dgs.id = dga.id_group_session
        LEFT JOIN
    dream_group dg ON dg.id = dgs.id_group
        LEFT JOIN
    dream_hub dh ON dh.id = dg.id_dream_hub
        LEFT JOIN
    lookup_commune lc ON lc.id = dh.commune
        LEFT JOIN
    lookup_departement ld ON ld.id = lc.departement
        LEFT JOIN
    lookup_dreams_topic ldt ON ldt.id = dgs.topic
        LEFT JOIN
    patient p ON p.id = dga.id_patient
        LEFT JOIN
    beneficiary b ON b.id_patient = dga.id_patient
        left join 
            auth_users au  on au.id=dgs.created_by
WHERE
    dga.value = 'P'
'''

attendance = pd.read_sql_query(query,engine,parse_dates=True)
# get the test excel file from Query

# close the pool of connection
engine.dispose()
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# c:\users\wedner adrien\appdata\local\programs\python\python39\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     731             try:
# --> 732                 data = self._rfile.read(num_bytes)
#     733                 break
#
# c:\users\wedner adrien\appdata\local\programs\python\python39\lib\socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
attendance.to_excel('./attendances.xlsx',index=False,na_rep="NULL")

# %%
attendance
# Out:
#               patient_code  first_name last_name         dob interview_date  \
# 0       PAP/DRMS/015004003     Wilgana     Means  2000-12-27     2020-01-30
# 1       PAP/DRMS/015004005      Selena    Selian  2001-11-01     2020-01-30
# 2       PAP/DRMS/015004006      olmise   dalmacy  2001-12-09     2020-01-30
# 3       PAP/DRMS/015004007    wideline    daniel  2001-01-04     2020-01-30
# 4       PAP/DRMS/015004016    Mirdwine    Aubain  2001-10-12     2020-01-30
# ...                    ...         ...       ...         ...            ...
# 331584  GON/DRMS/074212706  Chidelande    Israel  2008-08-18     2018-05-02
# 331585  GON/DRMS/053219105   claudinia    Glaude  2009-01-01     2020-07-14
# 331586  GON/DRMS/053219528   Nephtalie      Noël  2006-08-25     2020-07-13
# 331587  GON/DRMS/053220518     Sacrina    Fidèle  2007-07-12     2020-07-13
# 331588  GON/DRMS/078220404   Rosecania  Previlus  2009-04-13     2020-07-13
#
#        session_date                 group_name  \
# ...

# %% [markdown]
# ## Agents

# %%
attendance.dtypes
# Out:
# patient_code                         object
# first_name                           object
# last_name                            object
# dob                                  object
# interview_date                       object
# session_date                         object
# group_name                           object
# hub_name                             object
# hub_commune                          object
# hub_departement                      object
# interview_commune                    object
# topic                                object
# created_by                           object
# date_session_were_entered    datetime64[ns]
# dtype: object

# %%
attendance_deduplicate = attendance.drop_duplicates(subset=['patient_code'])

# %%
attendance_deduplicate
# Out:
#               patient_code first_name    last_name         dob interview_date  \
# 0       PAP/DRMS/015004003    Wilgana        Means  2000-12-27     2020-01-30
# 1       PAP/DRMS/015004005     Selena       Selian  2001-11-01     2020-01-30
# 2       PAP/DRMS/015004006     olmise      dalmacy  2001-12-09     2020-01-30
# 3       PAP/DRMS/015004007   wideline       daniel  2001-01-04     2020-01-30
# 4       PAP/DRMS/015004016   Mirdwine       Aubain  2001-10-12     2020-01-30
# ...                    ...        ...          ...         ...            ...
# 331104  PAP/DRMS/030232120   Valencia     Cherisme  2005-05-26     2020-11-15
# 331105  PAP/DRMS/030232121   Madeline     Acsilien  2006-01-06     2020-10-03
# 331106  PAP/DRMS/030232122    Jessica         Semé  1999-08-28     2020-10-14
# 331107  PAP/DRMS/030232123     Dieuna  Jean Pierre  2001-11-03     2020-12-19
# 331500  GON/DRMS/132151713    Adeline    Dieujuste  2008-01-01     2020-09-10
#
# ...

# %%
attendance_deduplicate[attendance_deduplicate['date_session_were_entered']>='2021-03-01']
# Out:
#               patient_code       first_name    last_name         dob  \
# 319173  PAP/DRMS/130165518  Woud Shdenaëlle     Filistin  2009-03-28
# 319191  PAP/DRMS/130163014      Woodberline      Jorilus  2007-08-16
# 319204  PAP/DRMS/032087217          Paulnar        Desir  2003-02-01
# 319205  PAP/DRMS/032087218           Briana     Thelusma  2004-12-24
# 319206  PAP/DRMS/032087219          Wishima       Cinéus  2004-10-13
# ...                    ...              ...          ...         ...
# 331104  PAP/DRMS/030232120         Valencia     Cherisme  2005-05-26
# 331105  PAP/DRMS/030232121         Madeline     Acsilien  2006-01-06
# 331106  PAP/DRMS/030232122          Jessica         Semé  1999-08-28
# 331107  PAP/DRMS/030232123           Dieuna  Jean Pierre  2001-11-03
# 331500  GON/DRMS/132151713          Adeline    Dieujuste  2008-01-01
#
#        interview_date session_date         group_name  \
# 319173     2020-11-20   2021-03-08          Valkiries
# ...

# %%
performance_session_global  = attendance_deduplicate[attendance_deduplicate['date_session_were_entered']>='2021-03-01'].groupby(['created_by']).count()

# %%
performance_session  = pd.DataFrame( {"nombre_de_filles": performance_session_global['patient_code']})

# %%
performance_session
# Out:
#                                               nombre_de_filles
# created_by
# billyjolicoeur95@gmail.com                                 211
# byronfabrice9@gmail.com                                    298
# diegoarmando.dorlean@carisfoundationintl.org                48
# elionafredly7@gmail.com                                     73
# ernst.belabre@carisfoundationintl.org                      135
# francenelstjean.saed@yahoo.com                              50
# gerald.poteau@carisfoundationintl.org                       46
# jhonip77@yahoo.fr                                           54
# roselord.despeignes@carisfoundationintl.org                 45

# %%
performance_session.to_excel('performance_session_agents.xlsx')

# %% [markdown]
# ## Agent per Commune

# %%
attendance_dedu_marsplus = attendance_deduplicate[attendance_deduplicate['date_session_were_entered']>='2021-03-01']

# %%
index_need   = list(attendance_dedu_marsplus.created_by.unique())

# %%
list(attendance_dedu_marsplus['created_by'].unique())
# Out:
# ['billyjolicoeur95@gmail.com',
#  'byronfabrice9@gmail.com',
#  'elionafredly7@gmail.com',
#  'francenelstjean.saed@yahoo.com',
#  'jhonip77@yahoo.fr',
#  'diegoarmando.dorlean@carisfoundationintl.org',
#  'ernst.belabre@carisfoundationintl.org',
#  'roselord.despeignes@carisfoundationintl.org',
#  'gerald.poteau@carisfoundationintl.org']

# %%
attendance_dedu_marsplus.pivot_table(index='created_by',columns='hub_commune',values='patient_code',aggfunc={'patient_code':'count'},fill_value=0,margins=True,margins_name="Total")
# Out:
# hub_commune                                   Cap-Haïtien  Carrefour  \
# created_by
# billyjolicoeur95@gmail.com                             22          0
# byronfabrice9@gmail.com                                 0         15
# diegoarmando.dorlean@carisfoundationintl.org            0          0
# elionafredly7@gmail.com                                 0         22
# ernst.belabre@carisfoundationintl.org                   0          0
# francenelstjean.saed@yahoo.com                          0          0
# gerald.poteau@carisfoundationintl.org                   0          0
# jhonip77@yahoo.fr                                       0          0
# roselord.despeignes@carisfoundationintl.org             0          0
# Total                                                  22         37
#
# hub_commune                                   Dessalines  Grande Saline  \
# created_by
# billyjolicoeur95@gmail.com                             0              0
# ...

# %%
attendance_dedu_marsplus.pivot_table(index='created_by',columns='hub_commune',values='patient_code',aggfunc={'patient_code':'count'},fill_value=0,margins=True,margins_name="Total")

# %%
performance_agents_par_commune = attendance_dedu_marsplus.pivot_table(index='created_by',columns='hub_commune',values='patient_code',aggfunc={'patient_code':'count'},fill_value=0,margins=True,margins_name="Total")

# %%
performance_agents_par_commune.to_excel('performance_session_agents_per_commune.xlsx')

# %% [markdown]
# ## Repporting Performance de mars 2021 a date

# %%
pac = pd.ExcelWriter('rapport_agents_saisie_des_sessions.xlsx',engine='xlsxwriter')
performance_session.to_excel(pac,sheet_name='filles_saisies_global')
performance_agents_par_commune.to_excel(pac,sheet_name="filles_saisies_par_communes")
pac.save()
