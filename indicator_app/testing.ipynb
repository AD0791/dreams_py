# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from base_dreams_session import agyw_service_session, agyw_service_hivinfo, mastersheet

# %%
agyw_service_session
# Out:
#                      Code last_name  first_name         dob  age  \
# 0      CAP/DRMS/022007805    Joseph  Berlandine  2005-05-28   16
# 1      PAP/DRMS/032035601  François       Accla  2005-12-06   15
# 2      PAP/DRMS/032035602    Pierre      Adassa  2010-05-10   11
# 3      GON/DRMS/047042401     dumas    Guerdine  2002-11-23   18
# 4      PAP/DRMS/032035603   Derilus    Wesnaika  2009-11-14   11
# ...                   ...       ...         ...         ...  ...
# 11286  PAP/DRMS/032302815     Louis     Stamany  2000-02-04   21
# 11287  PAP/DRMS/032302816   Charles     bethana  2002-09-04   19
# 11288  PAP/DRMS/032302817    victor     mitrose  2000-07-24   21
# 11289  PAP/DRMS/032302818    st cyr      edline  1999-02-08   22
# 11290  PAP/DRMS/032302819    Alcius      Stecie  2007-07-04   14
#
#        nbre_session  number_of_different_topic_for_inter  id_patient  \
# 0                 8                                  8.0       65440
# ...

# %%
agyw_service_hivinfo
# Out:
#                     Code last_name first_name         dob  age   test_date  \
# 0     PAP/DRMS/004005408    Jumeau   Jennifer  2004-05-25   17  0000-00-00
# 1     PAP/DRMS/004005410     Louis  Mykalexia  2002-04-11   19  0000-00-00
# 2     PAP/DRMS/032035602    Pierre     Adassa  2010-05-10   11  0000-00-00
# 3     CAP/DRMS/100071305   Docteur  Hershline  2005-10-02   15  0000-00-00
# 4     CAP/DRMS/100071306  Ambroise     stecie  2003-07-02   18  0000-00-00
# ...                  ...       ...        ...         ...  ...         ...
# 4138  PAP/DRMS/032302816   Charles    bethana  2002-09-04   19  2021-08-10
# 4139  PAP/DRMS/032302817    victor    mitrose  2000-07-24   21  2021-08-10
# 4140  PAP/DRMS/032302818    st cyr     edline  1999-02-08   22  2021-08-10
# 4141  PAP/DRMS/032302819    Alcius     Stecie  2007-07-04   14  2021-08-10
# 4142  PAP/DRMS/035018213     Jovin    Fabiola  2000-02-03   21  2021-09-11
#
# ...

# %%
mastersheet
# Out:
#        main_id muso_eligibility  actual_id_group group_she_take_sessions  \
# 0            0             no17             1895                    None
# 1        51353             no17                1                      1,
# 2        51354        yes_sup18                1                      1,
# 3        51355             no18                1                      1,
# 4        51356        yes_sup18                1                      1,
# ...        ...              ...              ...                     ...
# 29798   123923             no18             3028                   3028,
# 29799   123924             no18             3028                   3028,
# 29800   123925             no18             3028                   3028,
# 29801   123926             no18             3028                   3028,
# 29802   123927             no17             3028                   3028,
#
#                      code last_name      first_name         dob   age  \
# ...
