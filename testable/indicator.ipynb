# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from start import dreams_mastersheet

# %%
dreams_mastersheet
# Out:
#        main_id muso_eligibility  actual_id_group group_she_take_sessions  \
# 0            0             no17             1895                    None
# 1        51353             no17                1                      1,
# 2        51354        yes_sup18                1                      1,
# 3        51355             no18                1                      1,
# 4        51356        yes_sup18                1                      1,
# ...        ...              ...              ...                     ...
# 29215   123049             no17             2970                    None
# 29216   123050             no17             2970                    None
# 29217   123051             no17             2970                    None
# 29218   123052             no17             2970                    None
# 29219   123053             no17             2970                    None
#
#                      code last_name      first_name         dob   age  \
# ...
